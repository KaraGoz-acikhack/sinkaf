# %%
import numpy as np
import pandas as pd
import re
import string
import torch

from imblearn.over_sampling import SMOTE
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModel, pipeline

# %%
labels = pd.read_csv("sinkaf/data/troff-v1.0.tsv",  sep='\t')['label'] != 'non'
print(labels.value_counts())
# Out:
# False    28439
# True      6845
# Name: label, dtype: int64

# %%
# Onceden egitilmis Turkce BERT modeli kullanilarak deney derlemi vektore cevirilmistir
# https://drive.google.com/file/d/1fq_Vkvg0QFpZaG1EgwdhyXYNSLqdu2tq/view?usp=sharing
# Dosyayi indirip sinkaf/data'ya kopyalayiniz 
bert_data = pd.read_csv("sinkaf/data/bert_data.csv", header=None)

# %%
X_train, X_test, y_train, y_test = train_test_split(bert_data, labels)

# %%
# Az olan siniftaki degerlerden ornek uretimi
smote = SMOTE(sampling_strategy=1)
X_train, y_train = smote.fit_sample(bert_data, labels)

# %%
# basit NN egitimi
clf = MLPClassifier(
    hidden_layer_sizes=(128, 64, 32), max_iter=150, activation='relu', 
    solver='adam', alpha=1e-5, verbose=1, early_stopping=True)
clf.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.52592618
# Validation score: 0.777426
# Iteration 2, loss = 0.45636663
# Validation score: 0.799930
# Iteration 3, loss = 0.43379402
# Validation score: 0.806435
# Iteration 4, loss = 0.41607332
# Validation score: 0.789557
# Iteration 5, loss = 0.40778712
# Validation score: 0.814170
# Iteration 6, loss = 0.39313461
# Validation score: 0.827532
# Iteration 7, loss = 0.38391137
# Validation score: 0.829114
# Iteration 8, loss = 0.37975719
# Validation score: 0.826653
# Iteration 9, loss = 0.36511844
# Validation score: 0.823840
# Iteration 10, loss = 0.36128970
# Validation score: 0.826477
# Iteration 11, loss = 0.35013359
# Validation score: 0.839838
# Iteration 12, loss = 0.33610951
# Validation score: 0.838080
# Iteration 13, loss = 0.33081634
# Validation score: 0.841772
# Iteration 14, loss = 0.32964849
# Validation score: 0.835091
# Iteration 15, loss = 0.32088277
# Validation score: 0.819972
# Iteration 16, loss = 0.31065749
# Validation score: 0.845640
# Iteration 17, loss = 0.29909437
# Validation score: 0.848980
# Iteration 18, loss = 0.29674363
# Validation score: 0.846519
# Iteration 19, loss = 0.28780721
# Validation score: 0.846871
# Iteration 20, loss = 0.28511381
# Validation score: 0.848980
# Iteration 21, loss = 0.28429480
# Validation score: 0.836498
# Iteration 22, loss = 0.27073139
# Validation score: 0.862518
# Iteration 23, loss = 0.26832005
# Validation score: 0.854430
# Iteration 24, loss = 0.26249526
# Validation score: 0.864627
# Iteration 25, loss = 0.25085352
# Validation score: 0.852496
# Iteration 26, loss = 0.24925699
# Validation score: 0.859001
# Iteration 27, loss = 0.24079119
# Validation score: 0.868671
# Iteration 28, loss = 0.23379911
# Validation score: 0.863397
# Iteration 29, loss = 0.23178879
# Validation score: 0.872539
# Iteration 30, loss = 0.23066954
# Validation score: 0.867089
# Iteration 31, loss = 0.22760154
# Validation score: 0.867968
# Iteration 32, loss = 0.22302426
# Validation score: 0.868847
# Iteration 33, loss = 0.20813485
# Validation score: 0.874824
# Iteration 34, loss = 0.20909889
# Validation score: 0.878516
# Iteration 35, loss = 0.20909574
# Validation score: 0.875703
# Iteration 36, loss = 0.20352199
# Validation score: 0.870956
# Iteration 37, loss = 0.19826006
# Validation score: 0.871308
# Iteration 38, loss = 0.19294362
# Validation score: 0.875000
# Iteration 39, loss = 0.18967701
# Validation score: 0.873418
# Iteration 40, loss = 0.18706595
# Validation score: 0.884142
# Iteration 41, loss = 0.17975806
# Validation score: 0.880274
# Iteration 42, loss = 0.18051348
# Validation score: 0.877461
# Iteration 43, loss = 0.17367203
# Validation score: 0.882736
# Iteration 44, loss = 0.17109157
# Validation score: 0.885021
# Iteration 45, loss = 0.16580348
# Validation score: 0.875527
# Iteration 46, loss = 0.16571515
# Validation score: 0.892757
# Iteration 47, loss = 0.15487365
# Validation score: 0.871308
# Iteration 48, loss = 0.15883467
# Validation score: 0.883790
# Iteration 49, loss = 0.15836756
# Validation score: 0.888713
# Iteration 50, loss = 0.15021142
# Validation score: 0.888537
# Iteration 51, loss = 0.14765942
# Validation score: 0.888537
# Iteration 52, loss = 0.15356416
# Validation score: 0.879923
# Iteration 53, loss = 0.14510084
# Validation score: 0.875352
# Iteration 54, loss = 0.14488335
# Validation score: 0.892932
# Iteration 55, loss = 0.13890573
# Validation score: 0.882911
# Iteration 56, loss = 0.13989976
# Validation score: 0.885197
# Iteration 57, loss = 0.13571641
# Validation score: 0.887131
# Iteration 58, loss = 0.12647892
# Validation score: 0.892405
# Iteration 59, loss = 0.13156683
# Validation score: 0.888186
# Iteration 60, loss = 0.13134688
# Validation score: 0.897152
# Iteration 61, loss = 0.12417757
# Validation score: 0.872187
# Iteration 62, loss = 0.12496644
# Validation score: 0.893284
# Iteration 63, loss = 0.11940765
# Validation score: 0.884142
# Iteration 64, loss = 0.12882168
# Validation score: 0.891350
# Iteration 65, loss = 0.11737400
# Validation score: 0.884142
# Iteration 66, loss = 0.10994197
# Validation score: 0.889768
# Iteration 67, loss = 0.11779523
# Validation score: 0.890120
# Iteration 68, loss = 0.11432159
# Validation score: 0.895921
# Iteration 69, loss = 0.10634530
# Validation score: 0.901020
# Iteration 70, loss = 0.11613184
# Validation score: 0.899613
# Iteration 71, loss = 0.10301003
# Validation score: 0.903657
# Iteration 72, loss = 0.10843097
# Validation score: 0.897504
# Iteration 73, loss = 0.10510282
# Validation score: 0.895394
# Iteration 74, loss = 0.10061728
# Validation score: 0.901195
# Iteration 75, loss = 0.09521011
# Validation score: 0.892229
# Iteration 76, loss = 0.10366744
# Validation score: 0.892229
# Iteration 77, loss = 0.10292216
# Validation score: 0.903129
# Iteration 78, loss = 0.10190173
# Validation score: 0.892229
# Iteration 79, loss = 0.08713763
# Validation score: 0.905063
# Iteration 80, loss = 0.08881518
# Validation score: 0.888537
# Iteration 81, loss = 0.09242247
# Validation score: 0.898558
# Iteration 82, loss = 0.08858162
# Validation score: 0.891702
# Iteration 83, loss = 0.08808586
# Validation score: 0.897504
# Iteration 84, loss = 0.08505320
# Validation score: 0.894691
# Iteration 85, loss = 0.08313374
# Validation score: 0.863924
# Iteration 86, loss = 0.08801250
# Validation score: 0.905063
# Iteration 87, loss = 0.07949031
# Validation score: 0.899789
# Iteration 88, loss = 0.09115776
# Validation score: 0.901899
# Iteration 89, loss = 0.08899096
# Validation score: 0.890647
# Iteration 90, loss = 0.07506532
# Validation score: 0.900141
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(alpha=1e-05, early_stopping=True,
#               hidden_layer_sizes=(128, 64, 32), max_iter=150, verbose=1)

# %%
# Deney setinde %97, test setinde %95'e yakin basari
print("Train acc:\t{0:.3f}".format(clf.score(X_train, y_train)))
print("Test acc:\t{0:.3f}".format(clf.score(X_test, y_test)))

print(classification_report(y_train, clf.predict(X_train)))
print(classification_report(y_test, clf.predict(X_test)))
# Out:
# Train acc:	0.967
# Test acc:	0.949
#               precision    recall  f1-score   support
#
#        False       0.98      0.95      0.97     28439
#         True       0.95      0.98      0.97     28439
#
#     accuracy                           0.97     56878
#    macro avg       0.97      0.97      0.97     56878
# weighted avg       0.97      0.97      0.97     56878
#
#               precision    recall  f1-score   support
#
#        False       0.98      0.95      0.97      7106
#         True       0.82      0.94      0.88      1715
#
#     accuracy                           0.95      8821
#    macro avg       0.90      0.95      0.92      8821
# weighted avg       0.95      0.95      0.95      8821

# %%
# Pre-trained BERT kullanarak vektore cevirme
# Tek seferlik bir yukleme yapicak
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-128k-uncased")
bert = AutoModel.from_pretrained("dbmdz/bert-base-turkish-128k-uncased")

# %%
# Cumleleri vektore cevirirken eksik kisimlarda maximum uzunluga gore padding yapilmistir
# Max uzunluk sinkaf datasi icin 113
MAX_SENTENCE_TOKEN_LENGTH = 113

# %%
# Offensive? - Kufur mu?

test = [
    "lanet olasica pislik", 
    "tanisalim mi tatlim", 
    "yaz transfer sezonuna lionel messi damga vuracak gibi gözüküyor", 
    "dal sarkar kartal kalkar",
    "amk cocugu",
    "aq bebesindeki havaya bak sen",
    "kral cocuk bizim alper",
    "erol bulut istifa",
    "sen kendini ne saniyorsun kopek"]

# %%
tokenized = [tokenizer.encode(s, add_special_tokens=True) for s in test]
padded = np.array([s + [0]*(MAX_SENTENCE_TOKEN_LENGTH-len(s)) for s in tokenized])
input_ids = torch.tensor(np.array(padded)).to(torch.int64)

# %%
# Cumleleri vektore cevirme
def sentence_2_vec(input_id):
    with torch.no_grad():
        last_hidden_states = bert(input_id)
        features = last_hidden_states[0][:,0,:].numpy()
    return features

# %%
test_vector = sentence_2_vec(input_ids)
clf.predict(test_vector)
# Out:
# array([ True, False, False, False,  True,  True, False, False,  True])

# %%
import joblib

#dump it (higher), dump it (higher!)
joblib.dump(clf, "sinkaf/data/clf_nn.joblib")
# Out:
# ['sinkaf/data/clf_nn.joblib']
