# %%
import numpy as np
import pandas as pd
import re
import string
import torch

from imblearn.over_sampling import SMOTE
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModel, pipeline

# %%
labels = pd.read_csv("sinkaf/data/troff-v1.0.tsv",  sep='\t')['label'] != 'non'
print(labels.value_counts())
# Out:
# False    28439
# True      6845
# Name: label, dtype: int64

# %%
# Onceden egitilmis Turkce BERT modeli kullanilarak deney derlemi vektore cevirilmistir
# https://drive.google.com/file/d/1fq_Vkvg0QFpZaG1EgwdhyXYNSLqdu2tq/view?usp=sharing
# Dosyayi indirip sinkaf/data'ya kopyalayiniz 
bert_data = pd.read_csv("sinkaf/data/data_bert.csv", header=None)

# %%
X_train, X_test, y_train, y_test = train_test_split(bert_data, labels)

# %%
# Az olan siniftaki degerlerden ornek uretimi
smote = SMOTE(sampling_strategy=1)
X_train, y_train = smote.fit_sample(X_train, y_train)

# %%
# basit NN egitimi
clf = MLPClassifier(
    hidden_layer_sizes=(128, 64, 32), max_iter=150, activation='relu', 
    solver='adam', alpha=1e-5, verbose=1, early_stopping=True)
clf.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.53874775
# Validation score: 0.777908
# Iteration 2, loss = 0.46866646
# Validation score: 0.795065
# Iteration 3, loss = 0.44252566
# Validation score: 0.774853
# Iteration 4, loss = 0.42749733
# Validation score: 0.772503
# Iteration 5, loss = 0.41610360
# Validation score: 0.813161
# Iteration 6, loss = 0.41124527
# Validation score: 0.819506
# Iteration 7, loss = 0.39319176
# Validation score: 0.822797
# Iteration 8, loss = 0.38711474
# Validation score: 0.827497
# Iteration 9, loss = 0.37291859
# Validation score: 0.808696
# Iteration 10, loss = 0.36831250
# Validation score: 0.810106
# Iteration 11, loss = 0.35941692
# Validation score: 0.795770
# Iteration 12, loss = 0.34912841
# Validation score: 0.840658
# Iteration 13, loss = 0.34058314
# Validation score: 0.839248
# Iteration 14, loss = 0.33321302
# Validation score: 0.841833
# Iteration 15, loss = 0.32220876
# Validation score: 0.824912
# Iteration 16, loss = 0.31229393
# Validation score: 0.847709
# Iteration 17, loss = 0.31007318
# Validation score: 0.840188
# Iteration 18, loss = 0.30571661
# Validation score: 0.842068
# Iteration 19, loss = 0.29316949
# Validation score: 0.857344
# Iteration 20, loss = 0.28525860
# Validation score: 0.850999
# Iteration 21, loss = 0.27259672
# Validation score: 0.861810
# Iteration 22, loss = 0.26934600
# Validation score: 0.847709
# Iteration 23, loss = 0.26324047
# Validation score: 0.862280
# Iteration 24, loss = 0.26005840
# Validation score: 0.869565
# Iteration 25, loss = 0.25243769
# Validation score: 0.864630
# Iteration 26, loss = 0.24482058
# Validation score: 0.869330
# Iteration 27, loss = 0.24962240
# Validation score: 0.862280
# Iteration 28, loss = 0.23224258
# Validation score: 0.870035
# Iteration 29, loss = 0.23136028
# Validation score: 0.868155
# Iteration 30, loss = 0.22165937
# Validation score: 0.876381
# Iteration 31, loss = 0.21797082
# Validation score: 0.874266
# Iteration 32, loss = 0.21027205
# Validation score: 0.874501
# Iteration 33, loss = 0.20219710
# Validation score: 0.878261
# Iteration 34, loss = 0.19553134
# Validation score: 0.882491
# Iteration 35, loss = 0.20210923
# Validation score: 0.860400
# Iteration 36, loss = 0.18936158
# Validation score: 0.882961
# Iteration 37, loss = 0.19513239
# Validation score: 0.882256
# Iteration 38, loss = 0.18287836
# Validation score: 0.883901
# Iteration 39, loss = 0.18821099
# Validation score: 0.882491
# Iteration 40, loss = 0.17536478
# Validation score: 0.883901
# Iteration 41, loss = 0.17445152
# Validation score: 0.883901
# Iteration 42, loss = 0.17194880
# Validation score: 0.881316
# Iteration 43, loss = 0.17356812
# Validation score: 0.883431
# Iteration 44, loss = 0.16887792
# Validation score: 0.890717
# Iteration 45, loss = 0.16324204
# Validation score: 0.894947
# Iteration 46, loss = 0.15011415
# Validation score: 0.895182
# Iteration 47, loss = 0.15156874
# Validation score: 0.878496
# Iteration 48, loss = 0.15015885
# Validation score: 0.899882
# Iteration 49, loss = 0.14476646
# Validation score: 0.896827
# Iteration 50, loss = 0.15165340
# Validation score: 0.889542
# Iteration 51, loss = 0.13422147
# Validation score: 0.884136
# Iteration 52, loss = 0.13846245
# Validation score: 0.893067
# Iteration 53, loss = 0.13536347
# Validation score: 0.894007
# Iteration 54, loss = 0.13277632
# Validation score: 0.897062
# Iteration 55, loss = 0.13568436
# Validation score: 0.903643
# Iteration 56, loss = 0.13378137
# Validation score: 0.900588
# Iteration 57, loss = 0.12540285
# Validation score: 0.893302
# Iteration 58, loss = 0.13048662
# Validation score: 0.899177
# Iteration 59, loss = 0.10882096
# Validation score: 0.885781
# Iteration 60, loss = 0.12807354
# Validation score: 0.892127
# Iteration 61, loss = 0.11286799
# Validation score: 0.902703
# Iteration 62, loss = 0.10755113
# Validation score: 0.894712
# Iteration 63, loss = 0.11730591
# Validation score: 0.906933
# Iteration 64, loss = 0.10232831
# Validation score: 0.904348
# Iteration 65, loss = 0.10800340
# Validation score: 0.905758
# Iteration 66, loss = 0.09665704
# Validation score: 0.905523
# Iteration 67, loss = 0.09525390
# Validation score: 0.909283
# Iteration 68, loss = 0.10785156
# Validation score: 0.887662
# Iteration 69, loss = 0.10298347
# Validation score: 0.896357
# Iteration 70, loss = 0.08981609
# Validation score: 0.903408
# Iteration 71, loss = 0.09476870
# Validation score: 0.898002
# Iteration 72, loss = 0.09471844
# Validation score: 0.899882
# Iteration 73, loss = 0.09135491
# Validation score: 0.909048
# Iteration 74, loss = 0.09025709
# Validation score: 0.908108
# Iteration 75, loss = 0.08796489
# Validation score: 0.900588
# Iteration 76, loss = 0.07766801
# Validation score: 0.896357
# Iteration 77, loss = 0.09011762
# Validation score: 0.908343
# Iteration 78, loss = 0.08879135
# Validation score: 0.911868
# Iteration 79, loss = 0.07709666
# Validation score: 0.907638
# Iteration 80, loss = 0.08103835
# Validation score: 0.898707
# Iteration 81, loss = 0.08438620
# Validation score: 0.906933
# Iteration 82, loss = 0.07217548
# Validation score: 0.908108
# Iteration 83, loss = 0.08851656
# Validation score: 0.895887
# Iteration 84, loss = 0.07610557
# Validation score: 0.902703
# Iteration 85, loss = 0.08239661
# Validation score: 0.907403
# Iteration 86, loss = 0.07136508
# Validation score: 0.904583
# Iteration 87, loss = 0.07948671
# Validation score: 0.918684
# Iteration 88, loss = 0.05947120
# Validation score: 0.913514
# Iteration 89, loss = 0.07238901
# Validation score: 0.913043
# Iteration 90, loss = 0.06557600
# Validation score: 0.909518
# Iteration 91, loss = 0.06591638
# Validation score: 0.904583
# Iteration 92, loss = 0.07335963
# Validation score: 0.911163
# Iteration 93, loss = 0.05271179
# Validation score: 0.904818
# Iteration 94, loss = 0.07463923
# Validation score: 0.912103
# Iteration 95, loss = 0.06323776
# Validation score: 0.907403
# Iteration 96, loss = 0.06600114
# Validation score: 0.905993
# Iteration 97, loss = 0.05094108
# Validation score: 0.916334
# Iteration 98, loss = 0.04766487
# Validation score: 0.910928
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(alpha=1e-05, early_stopping=True,
#               hidden_layer_sizes=(128, 64, 32), max_iter=150, verbose=1)

# %%
# Deney setinde %97, test setinde %90'a yakin basari
print("Train acc:\t{0:.3f}".format(clf.score(X_train, y_train)))
print("Test acc:\t{0:.3f}".format(clf.score(X_test, y_test)))

print(classification_report(y_train, clf.predict(X_train)))
print(classification_report(y_test, clf.predict(X_test)))
# Out:
# Train acc:	0.976
# Test acc:	0.818
#               precision    recall  f1-score   support
#
#        False       0.97      0.98      0.98     21272
#         True       0.98      0.97      0.98     21272
#
#     accuracy                           0.98     42544
#    macro avg       0.98      0.98      0.98     42544
# weighted avg       0.98      0.98      0.98     42544
#
#               precision    recall  f1-score   support
#
#        False       0.89      0.89      0.89      7167
#         True       0.51      0.51      0.51      1654
#
#     accuracy                           0.82      8821
#    macro avg       0.70      0.70      0.70      8821
# weighted avg       0.82      0.82      0.82      8821

# %%
# Prepare final model
clf = MLPClassifier(
    hidden_layer_sizes=(128, 64, 32), max_iter=150, activation='relu', 
    solver='adam', alpha=1e-5, early_stopping=True)
clf.fit(bert_data, labels)
print("Train acc:\t{0:.3f}".format(clf.score(bert_data, labels)))
print(classification_report(y_train, clf.predict(X_train)))
# Out:
# Train acc:	0.857
#               precision    recall  f1-score   support
#
#        False       0.60      0.98      0.75     21272
#         True       0.94      0.36      0.52     21272
#
#     accuracy                           0.67     42544
#    macro avg       0.77      0.67      0.63     42544
# weighted avg       0.77      0.67      0.63     42544

# %%
# Pre-trained BERT kullanarak vektore cevirme
# Tek seferlik bir yukleme yapicak
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-128k-uncased")
bert = AutoModel.from_pretrained("dbmdz/bert-base-turkish-128k-uncased")
# Out:
# Downloading: 100%|██████████| 386/386 [00:00<00:00, 137kB/s]
# Downloading: 100%|██████████| 1.23M/1.23M [00:01<00:00, 1.18MB/s]
# Downloading: 100%|██████████| 59.0/59.0 [00:00<00:00, 8.80kB/s]
# Downloading: 100%|██████████| 740M/740M [04:22<00:00, 2.82MB/s]

# %%
# Cumleleri vektore cevirirken eksik kisimlarda maximum uzunluga gore padding yapilmistir
# Max uzunluk sinkaf datasi icin 113
MAX_SENTENCE_TOKEN_LENGTH = 113

# %%
# Offensive? - Kufur mu?

test = [
    "lanet olasica pislik", 
    "tanisalim mi tatlim", 
    "yaz transfer sezonuna lionel messi damga vuracak gibi gözüküyor", 
    "dal sarkar kartal kalkar",
    "amk cocugu",
    "aq bebesindeki havaya bak sen",
    "kralsin cocuk bizim alper",
    "erol bulut istifa",
    "sen kendini ne saniyorsun kopek"]

# %%
tokenized = [tokenizer.encode(s, add_special_tokens=True) for s in test]
padded = np.array([s + [0]*(MAX_SENTENCE_TOKEN_LENGTH-len(s)) for s in tokenized])
input_ids = torch.tensor(np.array(padded)).to(torch.int64)

# %%
# Cumleleri vektore cevirme
def sentence_2_vec(input_id):
    with torch.no_grad():
        last_hidden_states = bert(input_id)
        features = last_hidden_states[0][:,0,:].numpy()
    return features

# %%
test_vector = sentence_2_vec(input_ids)
clf.predict(test_vector)
# Out:
# array([ True, False, False, False,  True,  True, False, False, False])

# %%
import joblib

#dump it (higher), dump it (higher!)
joblib.dump(clf, "sinkaf/data/clf_nn.joblib")
# Out:
# ['sinkaf/data/clf_nn.joblib']
