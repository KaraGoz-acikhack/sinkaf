# %%
import numpy as np
import pandas as pd
import re
import string
import torch

from imblearn.over_sampling import SMOTE
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModel, pipeline

# %%
labels = pd.read_csv("sinkaf/data/troff-v1.0.tsv",  sep='\t')['label'] != 'non'
print(labels.value_counts())
# Out:
# False    28439
# True      6845
# Name: label, dtype: int64

# %%
# Onceden egitilmis Turkce BERT modeli kullanilarak deney derlemi vektore cevirilmistir
# https://drive.google.com/file/d/1fq_Vkvg0QFpZaG1EgwdhyXYNSLqdu2tq/view?usp=sharing
# Dosyayi indirip sinkaf/data'ya kopyalayiniz 
bert_data = pd.read_csv("sinkaf/data/bert_data.csv", header=None)

# %%
# Az olan siniftaki degerlerden ornek uretimi
smote = SMOTE(sampling_strategy=1)
bert_data, labels = smote.fit_sample(bert_data, labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(bert_data, labels)

# %%
# basit NN egitimi
clf = MLPClassifier(
    hidden_layer_sizes=(128, 64, 32), max_iter=150, activation='relu', 
    solver='adam', alpha=1e-5, verbose=1, early_stopping=True)
clf.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.53066189
# Validation score: 0.781997
# Iteration 2, loss = 0.46357644
# Validation score: 0.799812
# Iteration 3, loss = 0.44187904
# Validation score: 0.802157
# Iteration 4, loss = 0.43013017
# Validation score: 0.805438
# Iteration 5, loss = 0.42080317
# Validation score: 0.803797
# Iteration 6, loss = 0.40795082
# Validation score: 0.808251
# Iteration 7, loss = 0.39980172
# Validation score: 0.815752
# Iteration 8, loss = 0.39064890
# Validation score: 0.761369
# Iteration 9, loss = 0.38905256
# Validation score: 0.816456
# Iteration 10, loss = 0.37666436
# Validation score: 0.816456
# Iteration 11, loss = 0.36632882
# Validation score: 0.823254
# Iteration 12, loss = 0.35575864
# Validation score: 0.832630
# Iteration 13, loss = 0.34988470
# Validation score: 0.832865
# Iteration 14, loss = 0.34865826
# Validation score: 0.814580
# Iteration 15, loss = 0.33696291
# Validation score: 0.827239
# Iteration 16, loss = 0.32857582
# Validation score: 0.841069
# Iteration 17, loss = 0.31994413
# Validation score: 0.826770
# Iteration 18, loss = 0.31910683
# Validation score: 0.780591
# Iteration 19, loss = 0.31475002
# Validation score: 0.845054
# Iteration 20, loss = 0.30297458
# Validation score: 0.843179
# Iteration 21, loss = 0.29630379
# Validation score: 0.847632
# Iteration 22, loss = 0.29381762
# Validation score: 0.846695
# Iteration 23, loss = 0.28236178
# Validation score: 0.847867
# Iteration 24, loss = 0.28441280
# Validation score: 0.824895
# Iteration 25, loss = 0.26777551
# Validation score: 0.837553
# Iteration 26, loss = 0.26327231
# Validation score: 0.859119
# Iteration 27, loss = 0.26557204
# Validation score: 0.836146
# Iteration 28, loss = 0.26619625
# Validation score: 0.853258
# Iteration 29, loss = 0.24560664
# Validation score: 0.852086
# Iteration 30, loss = 0.24817272
# Validation score: 0.857243
# Iteration 31, loss = 0.24169506
# Validation score: 0.839428
# Iteration 32, loss = 0.24003288
# Validation score: 0.861228
# Iteration 33, loss = 0.22417425
# Validation score: 0.860759
# Iteration 34, loss = 0.22162547
# Validation score: 0.865448
# Iteration 35, loss = 0.21874032
# Validation score: 0.859822
# Iteration 36, loss = 0.22416960
# Validation score: 0.852321
# Iteration 37, loss = 0.21320430
# Validation score: 0.842710
# Iteration 38, loss = 0.21549101
# Validation score: 0.868729
# Iteration 39, loss = 0.20955249
# Validation score: 0.862869
# Iteration 40, loss = 0.19521408
# Validation score: 0.871308
# Iteration 41, loss = 0.18810812
# Validation score: 0.872480
# Iteration 42, loss = 0.19039604
# Validation score: 0.869667
# Iteration 43, loss = 0.19082952
# Validation score: 0.872949
# Iteration 44, loss = 0.18325074
# Validation score: 0.871308
# Iteration 45, loss = 0.17518534
# Validation score: 0.875059
# Iteration 46, loss = 0.18702331
# Validation score: 0.864510
# Iteration 47, loss = 0.16999817
# Validation score: 0.864979
# Iteration 48, loss = 0.17323458
# Validation score: 0.869198
# Iteration 49, loss = 0.16219152
# Validation score: 0.859353
# Iteration 50, loss = 0.16141438
# Validation score: 0.875293
# Iteration 51, loss = 0.16457537
# Validation score: 0.869902
# Iteration 52, loss = 0.15285814
# Validation score: 0.873418
# Iteration 53, loss = 0.14436541
# Validation score: 0.870605
# Iteration 54, loss = 0.14992496
# Validation score: 0.879747
# Iteration 55, loss = 0.16129696
# Validation score: 0.884669
# Iteration 56, loss = 0.15086164
# Validation score: 0.878809
# Iteration 57, loss = 0.14295722
# Validation score: 0.877403
# Iteration 58, loss = 0.13825106
# Validation score: 0.885842
# Iteration 59, loss = 0.13152496
# Validation score: 0.881857
# Iteration 60, loss = 0.13395626
# Validation score: 0.880684
# Iteration 61, loss = 0.13333991
# Validation score: 0.882560
# Iteration 62, loss = 0.13235925
# Validation score: 0.875293
# Iteration 63, loss = 0.12668198
# Validation score: 0.884669
# Iteration 64, loss = 0.12519328
# Validation score: 0.881622
# Iteration 65, loss = 0.12069918
# Validation score: 0.883732
# Iteration 66, loss = 0.12523016
# Validation score: 0.880450
# Iteration 67, loss = 0.12082708
# Validation score: 0.887482
# Iteration 68, loss = 0.11541605
# Validation score: 0.883497
# Iteration 69, loss = 0.11387786
# Validation score: 0.876934
# Iteration 70, loss = 0.10596050
# Validation score: 0.881857
# Iteration 71, loss = 0.11677302
# Validation score: 0.890999
# Iteration 72, loss = 0.10315651
# Validation score: 0.884435
# Iteration 73, loss = 0.10912971
# Validation score: 0.882325
# Iteration 74, loss = 0.09762965
# Validation score: 0.893108
# Iteration 75, loss = 0.10078934
# Validation score: 0.885607
# Iteration 76, loss = 0.10031372
# Validation score: 0.878106
# Iteration 77, loss = 0.09886974
# Validation score: 0.875996
# Iteration 78, loss = 0.08479409
# Validation score: 0.888889
# Iteration 79, loss = 0.09498077
# Validation score: 0.881622
# Iteration 80, loss = 0.10633640
# Validation score: 0.880450
# Iteration 81, loss = 0.09398196
# Validation score: 0.883029
# Iteration 82, loss = 0.08856335
# Validation score: 0.883029
# Iteration 83, loss = 0.09043299
# Validation score: 0.877403
# Iteration 84, loss = 0.09095466
# Validation score: 0.893108
# Iteration 85, loss = 0.09063889
# Validation score: 0.882560
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(alpha=1e-05, early_stopping=True,
#               hidden_layer_sizes=(128, 64, 32), max_iter=150, verbose=1)

# %%
# Deney setinde %97, test setinde %90'a yakin basari
print("Train acc:\t{0:.3f}".format(clf.score(X_train, y_train)))
print("Test acc:\t{0:.3f}".format(clf.score(X_test, y_test)))

print(classification_report(y_train, clf.predict(X_train)))
print(classification_report(y_test, clf.predict(X_test)))
# Out:
# Train acc:	0.967
# Test acc:	0.892
#               precision    recall  f1-score   support
#
#        False       0.97      0.96      0.97     21310
#         True       0.96      0.97      0.97     21348
#
#     accuracy                           0.97     42658
#    macro avg       0.97      0.97      0.97     42658
# weighted avg       0.97      0.97      0.97     42658
#
#               precision    recall  f1-score   support
#
#        False       0.92      0.86      0.89      7129
#         True       0.87      0.92      0.90      7091
#
#     accuracy                           0.89     14220
#    macro avg       0.89      0.89      0.89     14220
# weighted avg       0.89      0.89      0.89     14220

# %%
# Prepare final model
clf = MLPClassifier(
    hidden_layer_sizes=(128, 64, 32), max_iter=150, activation='relu', 
    solver='adam', alpha=1e-5, early_stopping=True)
clf.fit(bert_data, labels)
print("Train acc:\t{0:.3f}".format(clf.score(bert_data, labels)))
print(classification_report(y_train, clf.predict(X_train)))
# Out:
# Train acc:	0.967
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97     21310
#         True       0.96      0.98      0.97     21348
#
#     accuracy                           0.97     42658
#    macro avg       0.97      0.97      0.97     42658
# weighted avg       0.97      0.97      0.97     42658

# %%
# Pre-trained BERT kullanarak vektore cevirme
# Tek seferlik bir yukleme yapicak
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-128k-uncased")
bert = AutoModel.from_pretrained("dbmdz/bert-base-turkish-128k-uncased")

# %%
# Cumleleri vektore cevirirken eksik kisimlarda maximum uzunluga gore padding yapilmistir
# Max uzunluk sinkaf datasi icin 113
MAX_SENTENCE_TOKEN_LENGTH = 113

# %%
# Offensive? - Kufur mu?

test = [
    "lanet olasica pislik", 
    "tanisalim mi tatlim", 
    "yaz transfer sezonuna lionel messi damga vuracak gibi gözüküyor", 
    "dal sarkar kartal kalkar",
    "amk cocugu",
    "aq bebesindeki havaya bak sen",
    "kralsin cocuk bizim alper",
    "erol bulut istifa",
    "sen kendini ne saniyorsun kopek"]

# %%
tokenized = [tokenizer.encode(s, add_special_tokens=True) for s in test]
padded = np.array([s + [0]*(MAX_SENTENCE_TOKEN_LENGTH-len(s)) for s in tokenized])
input_ids = torch.tensor(np.array(padded)).to(torch.int64)

# %%
# Cumleleri vektore cevirme
def sentence_2_vec(input_id):
    with torch.no_grad():
        last_hidden_states = bert(input_id)
        features = last_hidden_states[0][:,0,:].numpy()
    return features

# %%
test_vector = sentence_2_vec(input_ids)
clf.predict(test_vector)
# Out:
# array([ True, False, False, False,  True,  True, False, False,  True])

# %%
import joblib

#dump it (higher), dump it (higher!)
joblib.dump(clf, "sinkaf/data/clf_nn.joblib")
# Out:
# ['sinkaf/data/clf_nn.joblib']
